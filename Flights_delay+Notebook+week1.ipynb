# %%
import pandas as pd
airlines= pd.read_csv('./flights.csv')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
airlines.head()
# Out:
# <bound method DataFrame.head of          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# 5        2015      1    1            4      DL            806      N3730B
# 6        2015      1    1            4      NK            612      N635NK
# 7        2015      1    1            4      US           2013      N584UW
# 8        2015      1    1            4      AA           1112      N3LAAA
# 9        2015      1    1            4      DL           1173      N826DN
# 10       2015      1    1            4      DL           2336      N958DN
# ...

# %%
import pandas as pd
airlines=pd.read_csv('./airlines.csv')

# %%
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airports=pd.read_csv('./airports.csv')

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
len(airports)
# Out:
# 322

# %%
flights=pd.read_csv('./flights.csv')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
flights.describe()
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-4b017797669c> in <module>()
# ----> 1 import pandas_profiling
#
# ImportError: No module named pandas_profiling

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-4b017797669c> in <module>()
# ----> 1 import pandas_profiling
#
# ImportError: No module named pandas_profiling

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(flights)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-874068e27b31> in <module>()
# ----> 1 pandas_profiling.ProfileReport(flights)
#
# NameError: name 'flights' is not defined

# %%
import pandas as pd
airlines=pd.read_csv('./airlines.csv')
airports=pd.read_csv('./airports.csv')
flights=pd.read_csv('./flights.csv')
# Out:
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pandas_profiling.ProfileReport(flights)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
flights.sort('DEPARTURE_DELAY', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9c289707be89> in <module>()
# ----> 1 flights.sort('DEPARTURE_DELAY', ascending=False)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
pd.sort('DEPARTURE_DELAY', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-cc4dea85e476> in <module>()
# ----> 1 pd.sort('DEPARTURE_DELAY', ascending=False)
#
# AttributeError: 'module' object has no attribute 'sort'

# %%
pd.sort_values('DEPARTURE_DELAYS', acending= False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-af9eea2cc402> in <module>()
# ----> 1 pd.sort_values('DEPARTURE_DELAYS', acending= False)
#
# AttributeError: 'module' object has no attribute 'sort_values'

# %%
flights.sort_values('DEPARTURE_DELAYS', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-70417d7e3c33> in <module>()
# ----> 1 flights.sort_values('DEPARTURE_DELAYS', ascending=False)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# ...

# %%
flights.sort_values('DEPARTURE_DELAY', ascending=False)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 337720   2015      1   23            5      AA           1322      N598AA
# 3412085  2015      8    1            6      AA             96      N479AA
# 4103531  2015      9   13            7      AA           1063      N3CAAA
# 5810811  2015     12   31            4      AA           2214      N4XKAA
# 5279939  2015     11   27            5      AA           2559      N489AA
# 3100911  2015      7   13            1      AA           1319      N3LEAA
# 1278418  2015      3   24            2      AA           1279      N559AA
# 264495   2015      1   18            7      AA            224      N5DGAA
# 949876   2015      3    4            3      AA            270      N5DJAA
# 886984   2015      2   28            6      AA           1312      N028AA
# 5538739  2015     12   14            1      AA           1310      N424AA
# 4559743  2015     10   12            1      AA           1308      N3BFAA
# ...

# %%
head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-959d86c5429a> in <module>()
# ----> 1 head(5)
#
# NameError: name 'head' is not defined

# %%
flights.head(5)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# ...

# %%
flights.sort_values('DEPARTURE_DELAY', ascending=False).head(10)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 337720   2015      1   23            5      AA           1322      N598AA
# 3412085  2015      8    1            6      AA             96      N479AA
# 4103531  2015      9   13            7      AA           1063      N3CAAA
# 5810811  2015     12   31            4      AA           2214      N4XKAA
# 5279939  2015     11   27            5      AA           2559      N489AA
# 3100911  2015      7   13            1      AA           1319      N3LEAA
# 1278418  2015      3   24            2      AA           1279      N559AA
# 264495   2015      1   18            7      AA            224      N5DGAA
# 949876   2015      3    4            3      AA            270      N5DJAA
# 886984   2015      2   28            6      AA           1312      N028AA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 337720             BHM                 DFW                  700
# ...

# %%
print flights.ORIGIN_AIRPORT
# Out:
# 0          ANC
# 1          LAX
# 2          SFO
# 3          LAX
# 4          SEA
# 5          SFO
# 6          LAS
# 7          LAX
# 8          SFO
# 9          LAS
# 10         DEN
# 11         LAS
# 12         LAX
# 13         SLC
# 14         SEA
# 15         ANC
# 16         ANC
# 17         SFO
# 18         ANC
# 19         PDX
# 20         LAS
# 21         SEA
# 22         LAS
# 23         LAX
# 24         LAS
# 25         LAX
# 26         FAI
# 27         MSP
# 28         LAS
# 29         DEN
#           ...
# 5819049    LAX
# 5819050    PHX
# 5819051    SEA
# 5819052    LAS
# 5819053    SEA
# 5819054    LAX
# 5819055    LAX
# 5819056    KOA
# 5819057    FLL
# 5819058    PHX
# 5819059    DEN
# 5819060    DEN
# 5819061    DEN
# 5819062    DEN
# 5819063    SEA
# 5819064    LAS
# 5819065    PDX
# 5819066    LAS
# 5819067    DEN
# 5819068    LAX
# 5819069    LAS
# 5819070    RNO
# 5819071    SLC
# 5819072    DEN
# 5819073    ABQ
# 5819074    LAX
# 5819075    JFK
# ...
